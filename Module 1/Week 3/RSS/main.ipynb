# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'
feedburner = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
feedburner.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
feedburner.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'id', 'guidislink', 'link', 'updated', 'updated_parsed', 'subtitle', 'subtitle_detail', 'links', 'authors', 'author_detail', 'author', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
feedburner.feed.title
# Out:
# "All - O'Reilly Media"

# %%
feedburner.feed.subtitle
# Out:
# 'All of our Ideas and Learning material from all of our topics.'

# %%
feedburner.feed.author
# Out:
# "O'Reilly Media"

# %%
feedburner.feed.link
# Out:
# 'https://www.oreilly.com'

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(feedburner.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
feedburner.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'updated', 'updated_parsed', 'id', 'guidislink', 'link', 'content', 'summary', 'links', 'authors', 'author_detail', 'author', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = [feedburner.entries[i].title for i in range(len(feedburner.entries))]
print(titles)
# Out:
# ['Four short links: 19 July 2019', 'The war for the soul of open source', 'Ask not what Brands™ can do for you', 'O’Reilly Radar: Open source technology trends—What our users tell us', "O'Reilly Open Source and Frank Willison Awards", 'Managing machines', 'Acquiring and sharing high-quality data', 'Four short links: 18 July 2019', 'Better living through software', 'Built to last: Building and growing open source communities', 'The next age of open innovation', "Highlights from the O'Reilly Open Source Software Conference in Portland 2019", 'The role of open source in mitigating natural disasters', 'Why Amazon cares about open source', 'Four short links: 17 July 2019', 'Four short links: 16 July 2019', 'Managing machine learning in the enterprise: Lessons from banking and health care', 'Four short links: 15 July 2019', 'Four short links: 12 July 2019', 'Four short links: 11 July 2019', 'Four short links: 10 July 2019', 'Four short links: 9 July 2019', 'The circle of fairness', "Highlights from the O'Reilly Artificial Intelligence Conference in Beijing 2019", 'Toward learned algorithms, data structures, and systems', 'Top AI breakthroughs you need to know', 'AI and retail', 'The future of hiring and the talent market with AI', 'AI and systems at RISELab', 'Data orchestration for AI, big data, and cloud', 'Designing computer hardware for artificial intelligence', 'The future of machine learning is tiny', 'Four short links: 8 July 2019', 'Four short links: 5 July 2019', 'Four short links: 4 July 2019', 'Tools for machine learning development', 'New live online training courses', 'Four short links: 3 July 2019', 'Four short links: 2 July 2019', 'Four short links: 1 July 2019', 'RISELab’s AutoPandas hints at automation tech that will change the nature of software development', 'Four short links: 28 June 2019', 'One simple chart: Who is interested in Spark NLP?', 'Four short links: 27 June 2019', 'Four short links: 26 June 2019', 'AI and machine learning will require retraining your entire organization', 'Four short links: 25 June 2019', 'Four short links: 24 June 2019', 'Four short links: 21 June 2019', 'Four short links: 20 June 2019', 'Enabling end-to-end machine learning pipelines in real-world applications', 'Four short links: 19 June 2019', 'What are model governance and model operations?', 'Four short links: 18 June 2019', 'The quest for high-quality data', 'Four short links: 17 June 2019', 'Prioritizing technical debt as if time and money mattered', 'From the trenches with Rebecca Parsons', 'Choices of scale', 'Four short links: 14 June 2019']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
(len([title for title in titles if "Four short links" in title])/len(feedburner.entries))
# Out:
# 0.43333333333333335

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(feedburner.entries)
df.head()
# Out:
#            author               author_detail                       authors  \
# 0  Nat Torkington  {'name': 'Nat Torkington'}  [{'name': 'Nat Torkington'}]
# 1      Adam Jacob      {'name': 'Adam Jacob'}      [{'name': 'Adam Jacob'}]
# 2     VM Brasseur     {'name': 'VM Brasseur'}     [{'name': 'VM Brasseur'}]
# 3  Roger Magoulas  {'name': 'Roger Magoulas'}  [{'name': 'Roger Magoulas'}]
# 4             NaN                         NaN                           NaN
#
#                                              content  \
# 0  [{'type': 'text/html', 'language': None, 'base...
# 1  [{'type': 'text/html', 'language': None, 'base...
# 2  [{'type': 'text/html', 'language': None, 'base...
# 3  [{'type': 'text/html', 'language': None, 'base...
# 4  [{'type': 'text/html', 'language': None, 'base...
#
#                                  feedburner_origlink  guidislink  \
# 0  https://www.oreilly.com/ideas/four-short-links...        True
# 1  https://www.oreilly.com/ideas/the-war-for-the-...        True
# 2  https://www.oreilly.com/ideas/ask-not-what-bra...        True
# 3  https://www.oreilly.com/ideas/oreilly-radar-op...        True
# 4  https://www.oreilly.com/ideas/oreilly-open-sou...        True
#
#                                                   id  \
# 0  tag:www.oreilly.com,2019-07-19:/ideas/four-sho...
# 1  tag:www.oreilly.com,2019-07-18:/ideas/the-war-...
# 2  tag:www.oreilly.com,2019-07-18:/ideas/ask-not-...
# 3  tag:www.oreilly.com,2019-07-18:/ideas/oreilly-...
# 4  tag:www.oreilly.com,2019-07-18:/ideas/oreilly-...
#
#                                                 link  \
# 0  http://feedproxy.google.com/~r/oreilly/radar/a...
# 1  http://feedproxy.google.com/~r/oreilly/radar/a...
# 2  http://feedproxy.google.com/~r/oreilly/radar/a...
# 3  http://feedproxy.google.com/~r/oreilly/radar/a...
# 4  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                                links  \
# 0  [{'href': 'http://feedproxy.google.com/~r/orei...
# 1  [{'href': 'http://feedproxy.google.com/~r/orei...
# 2  [{'href': 'http://feedproxy.google.com/~r/orei...
# 3  [{'href': 'http://feedproxy.google.com/~r/orei...
# 4  [{'href': 'http://feedproxy.google.com/~r/orei...
#
#                                              summary  \
# 0  <p><em>Journal Mining, API Use, Better Convers...
# 1  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 2  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 3  <p><img src='https://d3ucjech6zwjp8.cloudfront...
# 4  <p><img src='https://d3ucjech6zwjp8.cloudfront...
#
#                                                title  \
# 0                     Four short links: 19 July 2019
# 1                The war for the soul of open source
# 2                Ask not what Brands™ can do for you
# 3  O’Reilly Radar: Open source technology trends—...
# 4     O'Reilly Open Source and Frank Willison Awards
#
#                                         title_detail               updated  \
# 0  {'type': 'text/plain', 'language': None, 'base...  2019-07-19T17:05:00Z
# 1  {'type': 'text/plain', 'language': None, 'base...  2019-07-18T20:00:00Z
# 2  {'type': 'text/plain', 'language': None, 'base...  2019-07-18T20:00:00Z
# 3  {'type': 'text/plain', 'language': None, 'base...  2019-07-18T20:00:00Z
# 4  {'type': 'text/plain', 'language': None, 'base...  2019-07-18T20:00:00Z
#
#                        updated_parsed
# 0  (2019, 7, 19, 17, 5, 0, 4, 200, 0)
# 1  (2019, 7, 18, 20, 0, 0, 3, 199, 0)
# 2  (2019, 7, 18, 20, 0, 0, 3, 199, 0)
# 3  (2019, 7, 18, 20, 0, 0, 3, 199, 0)
# 4  (2019, 7, 18, 20, 0, 0, 3, 199, 0)

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#                                    author  entries
# 18                         Nat Torkington       26
# 5                              Ben Lorica        5
# 6   Ben Lorica, Harish Doddi, David Talby        2
# 10                              Jenn Webb        2
# 0                        Abigail Hing Wen        1
# 15                          Michael James        1
# 25                             Tim Kraska        1
# 24                           Tiffani Bell        1
# 23                         Roger Magoulas        1
# 22             Rebecca Parsons, Neal Ford        1
# 21                            Pete Warden        1
# 20                         Pete Skomoroch        1
# 19                 Pedro Cruz, Brad Topol        1
# 17                            Mikio Braun        1
# 16                          Mike Loukides        1
# 13                            Maria Zhang        1
# 14                       Michael Feathers        1
# 1                              Adam Jacob        1
# 12                             Mac Slocum        1
# 11                           Kay Williams        1
# 9                              Ion Stoica        1
# 8                  Ihab Ilyas, Ben Lorica        1
# 7                              Haoyuan Li        1
# 4                              Arun Gupta        1
# 3                         Alison McCauley        1
# 2                           Adam Tornhill        1
# 26                            VM Brasseur        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['title', 'author', 'title_length']].sort_values('title_length', ascending=False)
# Out:
#                                                 title  \
# 40  RISELab’s AutoPandas hints at automation tech ...
# 16  Managing machine learning in the enterprise: L...
# 23  Highlights from the O'Reilly Artificial Intell...
# 11  Highlights from the O'Reilly Open Source Softw...
# 50  Enabling end-to-end machine learning pipelines...
# 45  AI and machine learning will require retrainin...
# 3   O’Reilly Radar: Open source technology trends—...
# 9   Built to last: Building and growing open sourc...
# 56  Prioritizing technical debt as if time and mon...
# 24  Toward learned algorithms, data structures, an...
# 12  The role of open source in mitigating natural ...
# 30  Designing computer hardware for artificial int...
# 27  The future of hiring and the talent market wit...
# 42  One simple chart: Who is interested in Spark NLP?
# 52    What are model governance and model operations?
# 29     Data orchestration for AI, big data, and cloud
# 4      O'Reilly Open Source and Frank Willison Awards
# 6             Acquiring and sharing high-quality data
# 35             Tools for machine learning development
# 31             The future of machine learning is tiny
# 57             From the trenches with Rebecca Parsons
# 25              Top AI breakthroughs you need to know
# 1                 The war for the soul of open source
# 2                 Ask not what Brands™ can do for you
# 13                 Why Amazon cares about open source
# 36                   New live online training courses
# 10                    The next age of open innovation
# 54                    The quest for high-quality data
# 46                     Four short links: 25 June 2019
# 47                     Four short links: 24 June 2019
# 48                     Four short links: 21 June 2019
# 49                     Four short links: 20 June 2019
# 51                     Four short links: 19 June 2019
# 44                     Four short links: 26 June 2019
# 43                     Four short links: 27 June 2019
# 55                     Four short links: 17 June 2019
# 53                     Four short links: 18 June 2019
# 41                     Four short links: 28 June 2019
# 0                      Four short links: 19 July 2019
# 20                     Four short links: 10 July 2019
# 19                     Four short links: 11 July 2019
# 7                      Four short links: 18 July 2019
# 8                      Better living through software
# 14                     Four short links: 17 July 2019
# 15                     Four short links: 16 July 2019
# 17                     Four short links: 15 July 2019
# 18                     Four short links: 12 July 2019
# 59                     Four short links: 14 June 2019
# 21                      Four short links: 9 July 2019
# 38                      Four short links: 2 July 2019
# 32                      Four short links: 8 July 2019
# 33                      Four short links: 5 July 2019
# 34                      Four short links: 4 July 2019
# 37                      Four short links: 3 July 2019
# 39                      Four short links: 1 July 2019
# 28                          AI and systems at RISELab
# 22                             The circle of fairness
# 5                                   Managing machines
# 58                                   Choices of scale
# 26                                      AI and retail
#
#                                    author  title_length
# 40                             Ben Lorica            97
# 16  Ben Lorica, Harish Doddi, David Talby            81
# 23                              Jenn Webb            79
# 11                             Mac Slocum            77
# 50                             Ben Lorica            73
# 45                             Ben Lorica            72
# 3                          Roger Magoulas            68
# 9                            Kay Williams            59
# 56                          Adam Tornhill            57
# 24                             Tim Kraska            55
# 12                 Pedro Cruz, Brad Topol            55
# 30                          Michael James            55
# 27                            Maria Zhang            50
# 42                             Ben Lorica            49
# 52  Ben Lorica, Harish Doddi, David Talby            47
# 29                             Haoyuan Li            46
# 4                                     NaN            46
# 6                              Ben Lorica            39
# 35                              Jenn Webb            38
# 31                            Pete Warden            38
# 57             Rebecca Parsons, Neal Ford            38
# 25                       Abigail Hing Wen            37
# 1                              Adam Jacob            35
# 2                             VM Brasseur            35
# 13                             Arun Gupta            34
# 36                                    NaN            32
# 10                        Alison McCauley            31
# 54                 Ihab Ilyas, Ben Lorica            31
# 46                         Nat Torkington            30
# 47                         Nat Torkington            30
# 48                         Nat Torkington            30
# 49                         Nat Torkington            30
# 51                         Nat Torkington            30
# 44                         Nat Torkington            30
# 43                         Nat Torkington            30
# 55                         Nat Torkington            30
# 53                         Nat Torkington            30
# 41                         Nat Torkington            30
# 0                          Nat Torkington            30
# 20                         Nat Torkington            30
# 19                         Nat Torkington            30
# 7                          Nat Torkington            30
# 8                            Tiffani Bell            30
# 14                         Nat Torkington            30
# 15                         Nat Torkington            30
# 17                         Nat Torkington            30
# 18                         Nat Torkington            30
# 59                         Nat Torkington            30
# 21                         Nat Torkington            29
# 38                         Nat Torkington            29
# 32                         Nat Torkington            29
# 33                         Nat Torkington            29
# 34                         Nat Torkington            29
# 37                         Nat Torkington            29
# 39                         Nat Torkington            29
# 28                             Ion Stoica            25
# 22                          Mike Loukides            22
# 5                          Pete Skomoroch            17
# 58                       Michael Feathers            16
# 26                            Mikio Braun            13

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
list_titles_ml = df[df['summary'].str.contains('machine learning')]['title']

# %%
print(list_titles_ml)
# Out:
# 6               Acquiring and sharing high-quality data
# 11    Highlights from the O'Reilly Open Source Softw...
# 16    Managing machine learning in the enterprise: L...
# 23    Highlights from the O'Reilly Artificial Intell...
# 31               The future of machine learning is tiny
# 35               Tools for machine learning development
# 36                     New live online training courses
# 40    RISELab’s AutoPandas hints at automation tech ...
# 45    AI and machine learning will require retrainin...
# 50    Enabling end-to-end machine learning pipelines...
# 52      What are model governance and model operations?
# 54                      The quest for high-quality data
# Name: title, dtype: object
