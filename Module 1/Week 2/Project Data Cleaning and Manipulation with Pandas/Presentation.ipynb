# %% [markdown]
# # Base de Dados
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Primeiros Passos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Padronização e limpeza dos dados
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Activity
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Age
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Countries
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sex
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Fatal?
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # To Do
#
# ![image.png](attachment:image.png)
